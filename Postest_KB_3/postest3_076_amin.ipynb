# %% [markdown]
# ## 2109106076
# ## Muhammad Amin Quthbi Arabi

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df = pd.read_csv('players_15.csv')

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4     167495  https://sofifa.com/player/167495/manuel-neuer/...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
# 2          A. Robben                         Arjen Robben   30  1984-01-23
# 3     Z. Ibrahimović                   Zlatan Ibrahimović   32  1981-10-03
# 4           M. Neuer                         Manuel Neuer   28  1986-03-27
#
#    height_cm  weight_kg  nationality                 club  overall  potential  \
# ...

# %%
data = df.groupby('overall').mean()
data.head()
# Out:
#              sofifa_id        age   height_cm  weight_kg  potential  \
# overall
# 40       213911.666667  27.000000  181.666667  72.666667  46.333333
# 41       223157.500000  17.000000  182.500000  69.000000  55.500000
# 42       217472.250000  17.500000  182.250000  74.500000  54.000000
# 43       142216.333333  28.333333  186.333333  76.666667  49.333333
# 44       223798.000000  17.600000  178.400000  69.400000  53.400000
#
#          value_eur  wage_eur  international_reputation  weak_foot  \
# overall
# 40             0.0       0.0                       1.0   2.666667
# 41             0.0       0.0                       1.0   2.500000
# 42             0.0       0.0                       1.0   2.500000
# 43             0.0       0.0                       1.0   2.000000
# 44             0.0       0.0                       1.0   2.000000
#
#          skill_moves  release_clause_eur  team_jersey_number  \
# overall
# 40          2.000000                 NaN           28.666667
# ...

# %% [markdown]
# ## Menampilkan Data Power Shoot Berdasarkan Overall menggunakan Scatter plot

# %%
plt.figure(figsize=(15,10))
plt.scatter(df['overall'], df['shooting'])
plt.title('Data power shoot berdasarkan overall')
plt.xlabel('Overall')
plt.ylabel('Shooting Power')
plt.show()

# %% [markdown]
# ## Menampilkan Presentasi kaki yang disukai dengan menggunakan Pie Chart

# %%
data = df.preferred_foot.value_counts()
plt.pie(data, labels=data.index, autopct="%1.1f%%")
plt.title('Persentase Kaki')
plt.show()

# %% [markdown]
# ## Menampilkan semua data dengan menggunakan HeatMap

# %%
plt.figure(figsize=(25,10))
cor_matrix = df.corr()
sns.heatmap(cor_matrix, cmap='coolwarm', annot=True, center=0)
plt.show()

# %% [markdown]
# ## Menampilkan data pace dengan Histogram

# %%
plt.hist(df['pace'], bins=25)
sns.set_style('darkgrid')
plt.title('Histogram data pace')
plt.ylabel('Frekuensi Pace')
plt.xlabel('Pace')
plt.show()
