# %% [markdown]
# # 2109106076
# # Muhammad Amin Quthbi Arabi

# %%
import pandas as pd

# %%
data = pd.read_csv('players_15.csv')
data
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# ...          ...                                                ...
# 15460     220806  https://sofifa.com/player/220806/ellis-redman/...
# 15461     225509  https://sofifa.com/player/225509/aaron-collins...
# 15462     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 15463     222947  https://sofifa.com/player/222947/tom-davies/15...
# 15464     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   27
# ...

# %% [markdown]
# ## Membagi dataset menjadi training set dan testing set dengan proporsi 70:30

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.iloc[:,:-1]
y = data.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
print("Dimensi X_train : ", X_train.shape)
print("Dimensi X_train : ", X_test.shape)
print("Dimensi y_train : ", y_train.shape)
print("Dimensi y_test : ", y_test.shape)
# Out:
# Dimensi X_train :  (10825, 103)
# Dimensi X_train :  (4640, 103)
# Dimensi y_train :  (10825,)
# Dimensi y_test :  (4640,)

# %% [markdown]
# ## Melakukan normalisasi data pada salah satu attribute menggunakan Min Max scaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
normalized_train_data = train_data.copy()
scaler = MinMaxScaler()
normalized_train_data['height_cm'] = scaler.fit_transform(normalized_train_data[['height_cm']])
normalized_train_data
# Out:
#        sofifa_id                                         player_url  \
# 4562      182641  https://sofifa.com/player/182641/bruno-manuel-...
# 14245     224971  https://sofifa.com/player/224971/lucas-daury/1...
# 8457      221543  https://sofifa.com/player/221543/matias-gonzal...
# 7556      205202  https://sofifa.com/player/205202/wojciech-goll...
# 1905      198706  https://sofifa.com/player/198706/luis-alberto-...
# ...          ...                                                ...
# 5191      147131  https://sofifa.com/player/147131/vitaliy-kales...
# 13418     216171  https://sofifa.com/player/216171/luca-ricciard...
# 5390      209130  https://sofifa.com/player/209130/renaldo-adega...
# 860       168530  https://sofifa.com/player/168530/jardel-nivald...
# 7270      208302  https://sofifa.com/player/208302/alex-gilbey/1...
#
#          short_name                       long_name  age         dob  \
# 4562    Bruno China    Bruno Manuel Rodrigues Silva   31  1982-08-05
# ...

# %% [markdown]
# ## Melakukan standarisasi pada dataset

# %%
from sklearn.preprocessing import StandardScaler

# %%
standardized_train_data = train_data.copy()
scaler = StandardScaler()
standardized_train_data[['weight_kg']] = scaler.fit_transform(standardized_train_data[['weight_kg']])
standardized_train_data
# Out:
#        sofifa_id                                         player_url  \
# 4562      182641  https://sofifa.com/player/182641/bruno-manuel-...
# 14245     224971  https://sofifa.com/player/224971/lucas-daury/1...
# 8457      221543  https://sofifa.com/player/221543/matias-gonzal...
# 7556      205202  https://sofifa.com/player/205202/wojciech-goll...
# 1905      198706  https://sofifa.com/player/198706/luis-alberto-...
# ...          ...                                                ...
# 5191      147131  https://sofifa.com/player/147131/vitaliy-kales...
# 13418     216171  https://sofifa.com/player/216171/luca-ricciard...
# 5390      209130  https://sofifa.com/player/209130/renaldo-adega...
# 860       168530  https://sofifa.com/player/168530/jardel-nivald...
# 7270      208302  https://sofifa.com/player/208302/alex-gilbey/1...
#
#          short_name                       long_name  age         dob  \
# 4562    Bruno China    Bruno Manuel Rodrigues Silva   31  1982-08-05
# ...

# %% [markdown]
# ## melakukan Data cleaning pada data dengan nilai nul

# %%
from sklearn.impute import SimpleImputer

# %%
data_cleaned = train_data.copy()
imputer = SimpleImputer(strategy='median')
data_cleaned[['gk_diving']] = imputer.fit_transform(data_cleaned[['gk_diving']])
imputer = SimpleImputer(strategy='mean')
data_cleaned[['gk_handling']] = imputer.fit_transform(data_cleaned[['gk_handling']])
print("\n Jumlah null setelah menggunakan SimpleImputer: ")
print(data_cleaned.isna().sum())
# Out:
#  Jumlah null setelah menggunakan SimpleImputer:
# sofifa_id        0
# player_url       0
# short_name       0
# long_name        0
# age              0
#               ...
# lb            1200
# lcb           1200
# cb            1200
# rcb           1200
# rb            1200
# Length: 104, dtype: int64

# %% [markdown]
# data["gk_diving"].fillna(data["gk_diving"].mean(), inplace=True)
# data.isna().any()

# %% [markdown]
# ## Melakukan Data cleaning pada data dengan nilai duplikat.

# %%
print("NIlai Duplikat: ")
data.duplicated().sum()
# Out:
# NIlai Duplikat:
# 2

# %%
data_duplikat = train_data.copy()
dd = pd.DataFrame(data_duplikat)

# %%
duplication_indices = [2, 3]
duplicated_data = data.loc[duplication_indices]
dd = pd.concat([data, duplicated_data])

# %%
dd.drop_duplicates(inplace=True)

# %%
print("NIlai Duplikat: ")
dd.duplicated().sum()
# Out:
# NIlai Duplikat:
# 0

# %% [markdown]
# ## Mengganti tipe data salah satu attribute angka

# %%
data_type_changed = train_data.copy()
data_type_changed['height_cm'] = data_type_changed['height_cm'].astype(float)
data_type_changed['height_cm']
# Out:
# 4562     182.0
# 14245    180.0
# 8457     183.0
# 7556     182.0
# 1905     182.0
#          ...
# 5191     173.0
# 13418    172.0
# 5390     183.0
# 860      192.0
# 7270     183.0
# Name: height_cm, Length: 10825, dtype: float64

# %% [markdown]
# ## Melakukan one hot encoding pada dataset

# %%
from sklearn.preprocessing import OneHotEncoder
# Deklarasikan kelas OneHotEncoder dan lakukantransformasi pada kolom yang ingin diubah
OneHotEncoder = OneHotEncoder(sparse=False)
pfEnc = OneHotEncoder.fit_transform(data[["preferred_foot"]])
pfEnc = pd.DataFrame(pfEnc)
data["Left"] = pfEnc[0]
data["Right"] = pfEnc[1]
data.head()
# Out:
# C:\Users\X\venv_B1-21\Amin_076\lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4     167495  https://sofifa.com/player/167495/manuel-neuer/...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
# 2          A. Robben                         Arjen Robben   30  1984-01-23
# ...
